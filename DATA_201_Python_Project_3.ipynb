# %% [markdown]
# <a href="https://colab.research.google.com/github/Thivadee19/LGCC_201DataAnalytic_Python_Project3/blob/main/DATA_201_Python_Project_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv("NYPD_Hate_Crimes.csv")
## I changed the way to 'read' the data by uploading in the Colab folder after I download the CSV file.. pretty interesting to know that it quit easy.

# %%
df
# Out:
#      Full Complaint ID  Complaint Year Number  ...  Arrest Date  Arrest Id
# 0      201900112220917                   2019  ...          NaN        NaN
# 1      201900112125917                   2019  ...          NaN        NaN
# 2      202100112173517                   2021  ...          NaN        NaN
# 3      201900112442817                   2019  ...   06/08/2019  M19626067
# 4      201900112618217                   2019  ...          NaN        NaN
# ..                 ...                    ...  ...          ...        ...
# 827    201912212568117                   2019  ...          NaN        NaN
# 828    201912212498017                   2019  ...          NaN        NaN
# 829    201912212334717                   2019  ...          NaN        NaN
# 830    202012312240017                   2020  ...          NaN        NaN
# 831    201912312372817                   2019  ...          NaN        NaN
#
# [832 rows x 15 columns]

# %%
missing_values = ["n/a", "na", "--", "?"]
df = pd.read_csv('NYPD_Hate_Crimes.csv', na_values=missing_values)
df
## Just checking and cleaning the missing value and df read.
# Out:
#      Full Complaint ID  Complaint Year Number  ...  Arrest Date  Arrest Id
# 0      201900112220917                   2019  ...          NaN        NaN
# 1      201900112125917                   2019  ...          NaN        NaN
# 2      202100112173517                   2021  ...          NaN        NaN
# 3      201900112442817                   2019  ...   06/08/2019  M19626067
# 4      201900112618217                   2019  ...          NaN        NaN
# ..                 ...                    ...  ...          ...        ...
# 827    201912212568117                   2019  ...          NaN        NaN
# 828    201912212498017                   2019  ...          NaN        NaN
# 829    201912212334717                   2019  ...          NaN        NaN
# 830    202012312240017                   2020  ...          NaN        NaN
# 831    201912312372817                   2019  ...          NaN        NaN
#
# [832 rows x 15 columns]

# %%
df.head()
## checking the colum name
# Out:
#    Full Complaint ID  Complaint Year Number  ...  Arrest Date  Arrest Id
# 0    201900112220917                   2019  ...          NaN        NaN
# 1    201900112125917                   2019  ...          NaN        NaN
# 2    202100112173517                   2021  ...          NaN        NaN
# 3    201900112442817                   2019  ...   06/08/2019  M19626067
# 4    201900112618217                   2019  ...          NaN        NaN
#
# [5 rows x 15 columns]

# %%
df.count()
## checking basic info
# Out:
# Full Complaint ID                832
# Complaint Year Number            832
# Month Number                     832
# Record Create Date               832
# Complaint Precinct Code          832
# Patrol Borough Name              832
# County                           832
# Law Code Category Description    832
# Offense Description              832
# PD Code Description              832
# Bias Motive Description          832
# Offense Category                 832
# Other Motive Description           0
# Arrest Date                      266
# Arrest Id                        266
# dtype: int64

# %%
df.tail()
# Out:
#      Full Complaint ID  Complaint Year Number  ...  Arrest Date Arrest Id
# 827    201912212568117                   2019  ...          NaN       NaN
# 828    201912212498017                   2019  ...          NaN       NaN
# 829    201912212334717                   2019  ...          NaN       NaN
# 830    202012312240017                   2020  ...          NaN       NaN
# 831    201912312372817                   2019  ...          NaN       NaN
#
# [5 rows x 15 columns]

# %%
df.describe(include=['object'])
## getting to know overal detail to understand the data and short summary.
# Out:
#        Record Create Date      Patrol Borough Name  ... Arrest Date  Arrest Id
# count                 832                      832  ...         266        266
# unique                473                        8  ...         171        265
# top            03/05/2019  PATROL BORO BKLYN SOUTH  ...  01/05/2021  B19610788
# freq                    6                      170  ...          10          2
#
# [4 rows x 10 columns]

# %%
dfcolum = df.drop('Other Motive Description', axis=1)
dfcolum
## Dropped the colum
# Out:
#      Full Complaint ID  Complaint Year Number  ...  Arrest Date  Arrest Id
# 0      201900112220917                   2019  ...          NaN        NaN
# 1      201900112125917                   2019  ...          NaN        NaN
# 2      202100112173517                   2021  ...          NaN        NaN
# 3      201900112442817                   2019  ...   06/08/2019  M19626067
# 4      201900112618217                   2019  ...          NaN        NaN
# ..                 ...                    ...  ...          ...        ...
# 827    201912212568117                   2019  ...          NaN        NaN
# 828    201912212498017                   2019  ...          NaN        NaN
# 829    201912212334717                   2019  ...          NaN        NaN
# 830    202012312240017                   2020  ...          NaN        NaN
# 831    201912312372817                   2019  ...          NaN        NaN
#
# [832 rows x 14 columns]

# %%
df2 = df[['PD Code Description', 'Bias Motive Description', 'County']]
df2
## I choose the specifit colum that I want to see as a 'df2'
# Out:
#                   PD Code Description     Bias Motive Description    County
# 0             AGGRAVATED HARASSMENT 1                 ANTI-JEWISH  NEW YORK
# 1      CRIMINAL MISCHIEF 4TH, GRAFFIT                 ANTI-JEWISH  NEW YORK
# 2            ASSAULT 2,1,UNCLASSIFIED               ANTI-HISPANIC  NEW YORK
# 3            ASSAULT 2,1,UNCLASSIFIED                 ANTI-MUSLIM  NEW YORK
# 4            ASSAULT 2,1,UNCLASSIFIED                  ANTI-WHITE  NEW YORK
# ..                                ...                         ...       ...
# 827    CRIMINAL MISCHIEF 4TH, GRAFFIT                  ANTI-BLACK  RICHMOND
# 828                         ASSAULT 3  ANTI-MALE HOMOSEXUAL (GAY)  RICHMOND
# 829    MISCHIEF,CRIMINAL,    UNCL 2ND                 ANTI-JEWISH  RICHMOND
# 830    CRIMINAL MISCHIEF 4TH, GRAFFIT                  ANTI-BLACK  RICHMOND
# 831  CRIMINAL MISCHIEF,UNCLASSIFIED 4                  ANTI-BLACK  RICHMOND
#
# [832 rows x 3 columns]

# %%
df2 = df.filter(['Complaint Year Number','License Type','Summons Number','Issue Date','Violation Time','Violation','Fine Amount','Payment Amount','Precinct','County',"Violation Status"])
display(df2)
# Out:
#      Complaint Year Number    County
# 0                     2019  NEW YORK
# 1                     2019  NEW YORK
# 2                     2021  NEW YORK
# 3                     2019  NEW YORK
# 4                     2019  NEW YORK
# ..                     ...       ...
# 827                   2019  RICHMOND
# 828                   2019  RICHMOND
# 829                   2019  RICHMOND
# 830                   2020  RICHMOND
# 831                   2019  RICHMOND
#
# [832 rows x 2 columns]

# %%
df.groupby(['Bias Motive Description'])['Complaint Year Number'].count().sort_values(ascending=False).plot(kind='bar')
## to seethe most 'Bias Motive Description' which happened to Anti-Jewish most

# %%
df.groupby(['Offense Category'])['Full Complaint ID'].count().sort_values(ascending=False).plot(kind='bar')
## This is showing that Religion Pratice is the top offense category.

# %%
df4 = df.groupby(['Patrol Borough Name'])['Full Complaint ID'].count().sort_values(ascending=False).plot(kind='pie')
## I do pie chart to see what area/ Patrol found most Hate crime hate.

# %%
df3 = df.groupby(['Complaint Year Number'])['Full Complaint ID'].count().sort_values(ascending=False).plot(kind='pie')
## another pie chart to see and it show 2019 have found most Hate crime if compared with 2020 and 2021.

# %%
Bias = df.groupby(['Bias Motive Description']) ['Full Complaint ID']

# %%
Bias.count()
## Total of the case
# Out:
# Bias Motive Description
# 60 YRS AND OLDER                       1
# ANTI-ARAB                              6
# ANTI-ASIAN                            81
# ANTI-BLACK                            85
# ANTI-BUDDHIST                          2
# ANTI-CATHOLIC                         15
# ANTI-FEMALE                           14
# ANTI-FEMALE HOMOSEXUAL (LESBIAN)      12
# ANTI-GENDER NON-CONFORMING             2
# ANTI-HINDU                             2
# ANTI-HISPANIC                         11
# ANTI-JEHOVAHS WITNESS                  1
# ANTI-JEWISH                          406
# ANTI-LGBT (MIXED GROUP)               11
# ANTI-MALE HOMOSEXUAL (GAY)            84
# ANTI-MULTI-RACIAL GROUPS               3
# ANTI-MUSLIM                           21
# ANTI-OTHER ETHNICITY                  13
# ANTI-OTHER RELIGION                    2
# ANTI-PHYSICAL DISABILITY               1
# ANTI-RELIGIOUS PRACTICE GENERALLY      2
# ANTI-TRANSGENDER                      19
# ...

# %%
Bias.count().plot()

# %% [markdown]
# Summary:
# This datat have give me the suprisingly result from what I assume, 2019 have the most case of hate crime reported which I thoughtit should be 2020 and most case that reported what from the Anti-Jewish and because of the religion Pratice is the top offense category.
# top 3 location which has found from Patrol boro bklyn north and Patrol boro bklyn south and Patrol boro manhattan south.
